# %%
# !pip install -U finance-datareader
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 시각화

# %%
import FinanceDataReader as fdr
import pandas as pd

df = fdr.DataReader('272210', '2018')
df.head()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2019-11-13  10371  10818   9611   9925  15462185       NaN
# 2019-11-14   9969  10505   9656  10416   3649312  0.049471
# 2019-11-15  10684  11176  10371  10908   5304317  0.047235
# 2019-11-18  10908  11221  10729  10908   2652187  0.000000
# 2019-11-19  10997  11042  10416  10640   1411800 -0.024569

# %%
df['Close'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.drop(['Volume','Change'], axis = 1).plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
# 파이썬 시각화 패키지 불러오기
import matplotlib.pyplot as plt
# %matplotlib inline

# 사용자 운영체제 확인
import platform
platform.system()

# 운영체제별 한글 폰트 설정
if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정


# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %%
# set axis labels
ax = df['Close'].plot(figsize = (12,6), title = 'price')
ax.autoscale(axis = 'x', tight  = True)
ax.set(xlabel = 'Date', ylabel = 'Close')
# Out:
# [Text(0.5, 0, 'Date'), Text(0, 0.5, 'Close')]

# %%
# X Limit
df['Close']['2020-01-01':'2021-05-01'].plot(figsize = (12,6)).autoscale(axis = 'x', tight = True)

# %%
df['Close'].plot(figsize=(12,6) , xlim =['2020-01-01', '2021-05-01'])
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# ### 최소값 최대값 찾기

# %%
df.loc['2020-01-01':'2021-05-01']['Close'].min()
# Out:
# 4229

# %%
df.loc['2020-01-01':'2021-05-01']['Close'].max()
# Out:
# 19760

# %% [markdown]
# 자유롭게 시각화와 추출 할 수 있어야 한다.

# %%
df['Close'].plot(figsize=(12,6) , xlim =['2020-01-01', '2020-09-01'], ylim = [4000, 10000])
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df['Close'].plot(figsize=(12,6) , xlim =['2020-01-01', '2020-09-01'], ylim = [4000, 10000],
                 ls = '--', c ='r')
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# ## Xticks

# %%
from matplotlib import dates
from matplotlib.dates import MO,TU,WE,TH, FR, SA, SU

# %%
ax = df['Close'].plot(figsize= (12,6), xlim =['2020-01-01', '2020-09-01'], ylim = [4000,9000])
ax.set(xlabel='')
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday = SU))

# %% [markdown]
# ### ★ strftime

# %%
from datetime import datetime
datetime(2023,2,8,16,13,30).strftime('%A, %B, %d, %Y, %I:%M:%S %p')
# Out:
# 'Wednesday, February, 08, 2023, 04:13:30 PM'

# %%
ax = df['Close'].plot(figsize= (12,6), xlim =['2020-01-01', '2020-09-01'], ylim = [4000,9000])
ax.set(xlabel='')
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday = SU))
ax.xaxis.set_major_formatter(dates.DateFormatter('%B-%d-%a'))

# %%
ax =df['Close'].plot(figsize= (12,6), xlim =['2020-01-01', '2020-09-01'], ylim = [4000,9000])
ax.set(xlabel='')
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday = SU))
ax.xaxis.set_major_formatter(dates.DateFormatter('%B-%d-%a'))

ax.xaxis.set_minor_locator(dates.MonthLocator())
ax.xaxis.set_minor_formatter(dates.DateFormatter('\n\n\n\n%b'))
